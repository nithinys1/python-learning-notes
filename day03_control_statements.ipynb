# %% [markdown]
# #python controler notes
#
# if :
#   print() ( always use two space for print because indentation )

# %%
a = 50
if a > 10:
    print("a is greater than 10")
# Out:
# a is greater than 10

# %%
if 66 > 60:
    print("you passed")
    print("congratulations")
else:
    print("you failed")
# Out:
# you passed
# congratulations

# %% [markdown]
# ##password #if else

# %%
a = 5
x = a**6
if x > 1000:
    print("x is greater than 1000")
else:
    print("x is less than or equal to 25")
# Out:
# x is greater than 1000

# %%
time = int(input("Enter the time (0-23): "))
if time > 0 and time < 5:
    print("good night")
else:
    if time >= 5 and time < 12:
        print ("good moning")
    else:
        if time >= 12 and time < 17 :
            print("goodenning")
        else:
            print("good night")
# Out:
# good night

# %%
time = input("Enter the time (0-23): ")
if time > "0" and time < "5":
    print("good night")
elif time >= "5" and time < "12":
    print ("good moning")
elif time >= "12" and time < "17" :
    print("goodenning")
else:    print("good night")
# Out:
# good night

# %%
x = 0
if x:
    print("true")
else:
    print("false")
# Out:
# false

# %%
amount = int(input("enter amount: "))

if amount % 500 == 0:
    print("you can withdraw the amount")
elif amount % 200 == 0:
    print("you can withdraw the amount")
elif amount > 500 and (amount - 500) % 200 == 0:
    # covers 700, 900, 1100, ...
    print("you can withdraw the amount")
else:
    print("you cannot withdraw the amount")
    print("you cannot withdraw the amount")
# Out:
# you cannot withdraw the amount
# you cannot withdraw the amount

# %%
400%500
# Out:
# 400

# %%
amount = int(input("enter amount: "))
if amount < 500 and (amount % 500 )% 200 == 0:
    print("you can withdraw the amount")
else:
    print("you cannot withdraw the amount")
# Out:
# you cannot withdraw the amount

# %% [markdown]
# You are given 3 integer angles(in degrees) A, B and C of a triangle. You have to tell whether the triangle is valid or not.
#
#
# A triangle is valid if sum of its angles equals to 180.
#
# NOTE: You have to take the input of 3 sides of triangle from the

# %%
a = int(input())
b = int(input())
c = int(input())
if a + b + c == 180:
      print("1")
else:
    print("0")
# Out:
# 1
