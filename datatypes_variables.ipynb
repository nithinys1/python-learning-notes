# %% [markdown]
# Day-1 : Data types, Variables, I/O

# %% [markdown]
# print("Hello World")

# %%
print(123+123)
# Out:
# 246

# %%
print("123"+"123")
# Out:
# 123123

# %%
a = 123
b = 23
print(a/b)
# Out:
# 5.3478260869565215

# %%
print(type(23))
print(type("123"))
print(type(123.3))
print(type(True))
print(type(3+4j))
a = 123
print(type(a))
print(8-5)
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>
# <class 'complex'>
# <class 'int'>
# 3

# %%
a = 123
b = a+a
print (b)
# true = 100
# print (true)
# Out:
# 246
# 100

# %%
name = input()
print ( "hello gd mrng my love", name)
# Out:
# Bhavana Nithin
# hello gd mrng my love Bhavana Nithin

# %%
x = 1
y = "hello"
num = y
y = 5
num = y
print(num,y)
# Out:
# 5 5

# %%
a = float(input("enter the first value:  "))
b = float(input("enter the last value: "))
print("the output is", a+b )
# Out:
# the output is 3.0
