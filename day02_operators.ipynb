# %% [markdown]
# operators
# a. Arithmatic Operators --> + - * /
# b. Orders of Operators --> BEDMAS
# c. int/bool -->
# d. Comparison Operators --> < > >= ==
# e. assign Operators --> =
# f. Logical operators --> and , or , not
